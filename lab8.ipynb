# %%
import nltk

# Tải các gói dữ liệu cần thiết từ NLTK
nltk.download('gutenberg')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('tagsets')
nltk.download('names')
nltk.download('punkt')
nltk.download('omw-1.4') # Cần thiết cho wordnet trên Colab
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Package names is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
print("--- Bài 1: Liệt kê các file trong Gutenberg corpus ---")
corpus_names = nltk.corpus.gutenberg.fileids()
print(corpus_names)
# Out:
# --- Bài 1: Liệt kê các file trong Gutenberg corpus ---
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']

# %%
from nltk.corpus import stopwords

print("--- Bài 2: Các ngôn ngữ hỗ trợ stopword ---")
languages = stopwords.fileids()
print(languages)

print("\n--- Bài 3: Kiểm tra stopword tiếng Pháp ---")
french_stopwords = stopwords.words('french')
print(french_stopwords[:15]) # In thử 15 từ đầu tiên
# Out:
# --- Bài 2: Các ngôn ngữ hỗ trợ stopword ---
# ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish', 'uzbek']
#
# --- Bài 3: Kiểm tra stopword tiếng Pháp ---
# ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle', 'en', 'et', 'eux', 'il', 'ils']

# %%
import nltk
from nltk.tokenize import word_tokenize

print("--- Bài 4: Loại bỏ stopword khỏi văn bản ---")
text = "This is a simple sentence to demonstrate removing stopwords from a text."
words = word_tokenize(text)
stop_words_eng = set(stopwords.words('english'))

filtered_text = [w for w in words if w.lower() not in stop_words_eng]
print("Gốc:", words)
print("Lọc:", filtered_text)

print("\n--- Bài 5: Bỏ qua các stopword khỏi danh sách ---")
print("Số lượng stopword ban đầu:", len(stop_words_eng))
words_to_remove = {'not', 'no'}
custom_stop_words = stop_words_eng - words_to_remove
print("Số lượng stopword sau khi bỏ qua 'not' và 'no':", len(custom_stop_words))
# Out:
# --- Bài 4: Loại bỏ stopword khỏi văn bản ---
# Gốc: ['This', 'is', 'a', 'simple', 'sentence', 'to', 'demonstrate', 'removing', 'stopwords', 'from', 'a', 'text', '.']
# Lọc: ['simple', 'sentence', 'demonstrate', 'removing', 'stopwords', 'text', '.']
#
# --- Bài 5: Bỏ qua các stopword khỏi danh sách ---
# Số lượng stopword ban đầu: 198
# Số lượng stopword sau khi bỏ qua 'not' và 'no': 196

# %%
from nltk.corpus import wordnet

print("--- Bài 6: Tìm định nghĩa và ví dụ ---")
syns = wordnet.synsets("computer")
print("Từ:", syns[0].name())
print("Định nghĩa:", syns[0].definition())
print("Ví dụ:", syns[0].examples())

print("\n--- Bài 7: Từ đồng nghĩa và trái nghĩa của từ 'good' ---")
synonyms = []
antonyms = []

for syn in wordnet.synsets("good"):
    for l in syn.lemmas():
        synonyms.append(l.name())
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())

print("Đồng nghĩa:", set(synonyms))
print("Trái nghĩa:", set(antonyms))
# Out:
# --- Bài 6: Tìm định nghĩa và ví dụ ---
# Từ: computer.n.01
# Định nghĩa: a machine for performing calculations automatically
# Ví dụ: []
#
# --- Bài 7: Từ đồng nghĩa và trái nghĩa của từ 'good' ---
# Đồng nghĩa: {'honorable', 'right', 'goodness', 'proficient', 'respectable', 'dependable', 'undecomposed', 'near', 'effective', 'in_effect', 'unspoilt', 'skilful', 'secure', 'ripe', 'beneficial', 'safe', 'sound', 'expert', 'upright', 'full', 'practiced', 'estimable', 'dear', 'in_force', 'commodity', 'adept', 'thoroughly', 'serious', 'soundly', 'salutary', 'just', 'well', 'good', 'honest', 'unspoiled', 'trade_good', 'skillful'}
# Trái nghĩa: {'badness', 'evil', 'ill', 'bad', 'evilness'}

# %%
import nltk
nltk.download('tagsets_json')

print("--- Bài 8: Xem tổng quan bộ tag cho Danh từ (NN) ---")
nltk.help.upenn_tagset('NN.*')
# Out:
# --- Bài 8: Xem tổng quan bộ tag cho Danh từ (NN) ---
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# [nltk_data] Downloading package tagsets_json to /root/nltk_data...
# ...

# %%
print("--- Bài 9: So sánh sự giống nhau của 2 danh từ ---")
noun1 = wordnet.synset('cat.n.01')
noun2 = wordnet.synset('dog.n.01')
print("Độ tương đồng giữa 'cat' và 'dog':", noun1.wup_similarity(noun2))

print("\n--- Bài 10: So sánh sự giống nhau của 2 động từ ---")
verb1 = wordnet.synset('run.v.01')
verb2 = wordnet.synset('sprint.v.01')
print("Độ tương đồng giữa 'run' và 'sprint':", verb1.wup_similarity(verb2))
# Out:
# --- Bài 9: So sánh sự giống nhau của 2 danh từ ---
# Độ tương đồng giữa 'cat' và 'dog': 0.8571428571428571
#
# --- Bài 10: So sánh sự giống nhau của 2 động từ ---
# Độ tương đồng giữa 'run' và 'sprint': 0.8571428571428571

# %%
from nltk.corpus import names
import random

male_names = names.words('male.txt')
female_names = names.words('female.txt')

print("--- Bài 11: Số lượng và 10 tên nam/nữ đầu tiên ---")
print(f"Nam: {len(male_names)} tên. 10 tên đầu: {male_names[:10]}")
print(f"Nữ: {len(female_names)} tên. 10 tên đầu: {female_names[:10]}")

print("\n--- Bài 12: 15 kết hợp ngẫu nhiên ---")
labeled_names = ([(name, 'male') for name in male_names] +
                 [(name, 'female') for name in female_names])
random.shuffle(labeled_names)
for name, label in labeled_names[:15]:
    print(f"{name}: {label}")

print("\n--- Bài 13: Trích xuất ký tự cuối ---")
featuresets = [(name[-1], gender) for (name, gender) in labeled_names]
print("10 đặc trưng đầu tiên (Ký tự cuối, Nhãn):")
print(featuresets[:10])
# Out:
# --- Bài 11: Số lượng và 10 tên nam/nữ đầu tiên ---
# Nam: 2943 tên. 10 tên đầu: ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim']
# Nữ: 5001 tên. 10 tên đầu: ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale']
#
# --- Bài 12: 15 kết hợp ngẫu nhiên ---
# Reginauld: male
# Ferguson: male
# Rogers: male
# Petey: male
# Lancelot: male
# Shane: male
# Tomasina: female
# Angy: female
# Stephani: female
# Doll: female
# Adnan: male
# Fred: male
# Raquel: female
# Ilse: female
# Gamaliel: male
#
# --- Bài 13: Trích xuất ký tự cuối ---
# 10 đặc trưng đầu tiên (Ký tự cuối, Nhãn):
# [('d', 'male'), ('n', 'male'), ('s', 'male'), ('y', 'male'), ('t', 'male'), ('e', 'male'), ('a', 'female'), ('y', 'female'), ('i', 'female'), ('l', 'female')]
